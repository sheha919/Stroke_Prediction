# %% [markdown]
# <a href="https://colab.research.google.com/github/sheha919/Heart_Faliure_Prediction/blob/main/heart_faliure_pred_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Information about the dataset
#
# source: https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction
#
# **Attribute Information**
# 1. Age: age of the patient [years]
# 2. Sex: sex of the patient [M: Male, F: Female]
# 3. ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic]
# 4. RestingBP: resting blood pressure [mm Hg]
# 5. Cholesterol: serum cholesterol [mm/dl]
# 6. FastingBS: fasting blood sugar [1: if FastingBS > 120 mg/dl, 0: otherwise]
# 7. RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), LVH: showing probable or definite left ventricular hypertrophy by Estes' criteria]
# 8. MaxHR: maximum heart rate achieved [Numeric value between 60 and 202]
# 9. ExerciseAngina: exercise-induced angina [Y: Yes, N: No]
# 10. Oldpeak: oldpeak = ST [Numeric value measured in depression]
# 11. ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping]
# 12. HeartDisease: output class [1: heart disease, 0: Normal]

# %% [markdown]
# #Import Libraries

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

from sklearn.model_selection import train_test_split 
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.metrics import ConfusionMatrixDisplay, classification_report, RocCurveDisplay
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn import set_config
set_config(display='diagram')

# %% [markdown]
# #Load Data

# %%
df = pd.read_csv('/content/heart.csv')
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#make a copy
ml_df = df.copy()
ml_df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# #Explore Data

# %%
ml_df.shape
# Out:
# (918, 12)

# %%
ml_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
#checking for duplicates
ml_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicates in the data set.

# %%
#checking for missing data
ml_df.isna().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# No missing data in the data set.

# %%
#checking for inconsistencies in categorical data
data_types = ml_df.dtypes
str_object = data_types[data_types=='object'].index

for i in str_object:
  print(f'Column Name: {i}')
  print(ml_df[i].value_counts())
  print('\n')
# Out:
# Column Name: Sex
# M    725
# F    193
# Name: Sex, dtype: int64
#
#
# Column Name: ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64
#
#
# Column Name: RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: RestingECG, dtype: int64
#
#
# Column Name: ExerciseAngina
# N    547
# Y    371
# Name: ExerciseAngina, dtype: int64
#
#
# Column Name: ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: ST_Slope, dtype: int64

# %% [markdown]
# - Seems like there are no inconsistencies in the categorical data
# - 'ST_Slope' can be selected as ordinal data while all other categorical data columns can be considered as nominal data

# %%
ml_df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
ml_df[ml_df['RestingBP']==0]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 449   55   M           NAP          0            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 449    155              N      1.5     Flat             1

# %% [markdown]
# - Generally. it is highly unusual to have zero blood pressure.
# - This might be incorrect data entry.

# %%
ml_df[ml_df['Cholesterol']==0]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 293   65   M           ASY        115            0          0     Normal
# 294   32   M            TA         95            0          1     Normal
# 295   61   M           ASY        105            0          1     Normal
# 296   50   M           ASY        145            0          1     Normal
# 297   57   M           ASY        110            0          1         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 514   43   M           ASY        122            0          0     Normal
# 515   63   M           NAP        130            0          1         ST
# 518   48   M           NAP        102            0          1         ST
# 535   56   M           ASY        130            0          0        LVH
# 536   62   M           NAP        133            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# I think its fine to have a zero cholesterol level.

# %% [markdown]
# # Data Analysis and Visualization

# %% [markdown]
# ## Univarient Analysis

# %%
ml_df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
str_num = data_types[data_types!='object'].index
str_num
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease'],
#       dtype='object')

# %%
fig, axes  = plt.subplots(ncols =2, nrows =3, figsize = (14,12), sharey=True)

for i in range(2):
  plt.figure()
  sns.histplot(data = ml_df, x = str_num[i], bins= 'auto', ax= axes[0, i],log_scale=(False, True), kde=True, color = '#8B2252')
  

for i in range(2,4):
  plt.figure()
  sns.histplot(data = ml_df, x = str_num[i], bins= 'auto', ax= axes[1, i-2], log_scale=(False, True), kde=True, color = '#8B2252')
for i in range(4,6):
  plt.figure()
  sns.histplot(data = ml_df, x = str_num[i], bins= 'auto', ax= axes[2, i-4], log_scale=(False, True), kde=True, color = '#8B2252')

fig.suptitle('The distribution of each numerical columns', fontsize = 22, fontweight = 'bold', y = 1.0)
# Out:
# Text(0.5, 1.0, 'The distribution of each numerical columns')

# %% [markdown]
# - Above diagram shows the distrubutions of nymerical columns in the data set except target variable.
# - There are few oultliers can be observed. They are;
#   - one occurance of zero blood pressure
#   - more than 100 occurances of zero cholesterol
#   - more than 100 occurances of zero fasting blood sugar
#   - more than 100 occurances of zero and very few negative values of ST numerical values for depression
# - Distributions of age and MaxHR look fine.
# - Seems like the dataset has use zero for missing data.
# - Therefore, data imputation is required here.
# - The 'FastingBS' has to drop from the database since it wouldn't help for the analysis even after the imputing data since it is hard to seperate missing and actual zero values to imply sugar levels less than 120 mg/dl
# - The negative values in 'Oldpeak' must be inconsistent data. So they need to convert to positive values.

# %%
#droping FastingBS column
ml_df.drop(columns = ['FastingBS'], axis = 1, inplace = True)
ml_df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol RestingECG  MaxHR  \
# 0   40   M           ATA        140          289     Normal    172
# 1   49   F           NAP        160          180     Normal    156
# 2   37   M           ATA        130          283         ST     98
# 3   48   F           ASY        138          214     Normal    108
# 4   54   M           NAP        150          195     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
#converting negative values from 'Oldpeak'
ml_df['Oldpeak'] = abs(ml_df['Oldpeak'] )
ml_df[ml_df['Oldpeak']<0]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, ChestPainType, RestingBP, Cholesterol, RestingECG, MaxHR, ExerciseAngina, Oldpeak, ST_Slope, HeartDisease]
# Index: []

# %% [markdown]
# Now there is no negative values in 'Oldpeak' column.

# %% [markdown]
# #Bivarient Analysis

# %%
plt.figure(figsize = (8,6))
ax = sns.scatterplot(data = ml_df, x = 'Age', y = 'RestingBP', hue = 'HeartDisease', palette="magma")
legend_labels, _= ax.get_legend_handles_labels()
ax.legend(legend_labels, ['Normal', 'Heart Disease'], bbox_to_anchor=(1,1))
ax.set_xlabel('Age (Years)', fontsize = 16)
ax.set_ylabel('Resting Blood Pressure (mm Hg)', fontsize = 16)
ax.set_title('Resting Blood Pressure Vs Age of the patients', fontsize = 18, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Resting Blood Pressure Vs Age of the patients')

# %%
plt.figure(figsize = (8,6))
ax = sns.scatterplot(data = ml_df, x = 'Age', y = 'Cholesterol', hue = 'HeartDisease', palette="magma")
legend_labels, _= ax.get_legend_handles_labels()
ax.legend(legend_labels, ['Normal', 'Heart Disease'], bbox_to_anchor=(1,1))
ax.set_xlabel('Age (Years)', fontsize = 16)
ax.set_ylabel('Cholesterol Level (mm/dl)', fontsize = 16)
ax.set_title('Cholesterol Level Vs Age of the patients', fontsize = 18, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Cholesterol Level Vs Age of the patients')

# %%
plt.figure(figsize = (8,6))
ax = sns.scatterplot(data = ml_df, x = 'Age', y = 'MaxHR', hue = 'HeartDisease', palette="magma")
legend_labels, _= ax.get_legend_handles_labels()
ax.legend(legend_labels, ['Normal', 'Heart Disease'], bbox_to_anchor=(1,1))
ax.set_xlabel('Age (Years)', fontsize = 16)
ax.set_ylabel('Maximum Heart Rate', fontsize = 16)
ax.set_title('Maximum Heart Rate Vs Age of the patients', fontsize = 18, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, 'Maximum Heart Rate Vs Age of the patients')

# %%
sns.barplot(data = df, y = 'ChestPainType', x = 'RestingBP', palette="magma")

# %%
sns.barplot(data = df, y= 'ChestPainType', x = 'Cholesterol', palette="magma")

# %%
sns.barplot(data = df, y= 'ChestPainType', x = 'MaxHR', palette="magma")
